# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, roc_auc_score
from tensorflow.keras.models import load_model

# Ensure Pillow is installed
# !pip install Pillow

import PIL  # Ensure Pillow is imported
# Out:
# Requirement already satisfied: Pillow in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (10.3.0)

# %%
import tensorflow as tf

gpus = tf.config.list_physical_devices("GPU")
if gpus:
    for gpu in gpus:
        print("Found a GPU with the name:", gpu)
else:
    print("Failed to detect a GPU.")
# Out:
# Found a GPU with the name: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
# !pip install scikit-learn
# !pip install matplotlib
# !pip install h5py
# !pip install scikit-plot
# !pip install seaborn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (1.5.0)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: matplotlib in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.19.2)
# Requirement already satisfied: six>=1.5 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: h5py in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (3.11.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from h5py) (1.26.4)
# Requirement already satisfied: scikit-plot in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (0.3.7)
# Requirement already satisfied: matplotlib>=1.4.0 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from scikit-plot) (3.9.0)
# Requirement already satisfied: scikit-learn>=0.18 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from scikit-plot) (1.5.0)
# Requirement already satisfied: scipy>=0.9 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from scikit-plot) (1.13.1)
# Requirement already satisfied: joblib>=0.10 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from scikit-plot) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (6.4.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from scikit-learn>=0.18->scikit-plot) (3.5.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=1.4.0->scikit-plot) (3.19.2)
# Requirement already satisfied: six>=1.5 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->scikit-plot) (1.16.0)
# Requirement already satisfied: seaborn in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from seaborn) (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.4.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.19.2)
# Requirement already satisfied: six>=1.5 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, ReLU, Add, GlobalAveragePooling2D, Dense, Dropout, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import zipfile

# %%
# Unzip the dataset (assuming it's already downloaded and located in the current directory)
zip_file_path = r"D:\140k Real and Fake Faces.zip"
extract_to_path = r"D:\New folder"

with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to_path)

print("Extraction complete.")
# Out:
# Extraction complete.

# %%
# List all available GPUs
gpus = tf.config.list_physical_devices("GPU")

if gpus:
    print("GPUs detected:")
    for gpu in gpus:
        print(f" - {gpu}")

    # Check if TensorFlow is using the GPU
    from tensorflow.python.client import device_lib
    devices = device_lib.list_local_devices()
    for device in devices:
        if device.device_type == "GPU":
            print(f"TensorFlow is using GPU: {device.name}")
else:
    print("No GPUs detected. TensorFlow will use the CPU.")
# Out:
# GPUs detected:
#  - PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# TensorFlow is using GPU: /device:GPU:0

# %%
# Custom Attention Layer
class AttentionLayer(Layer):
    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        self.W = self.add_weight(shape=(input_shape[-1], input_shape[-1]),
                                 initializer='glorot_uniform',
                                 trainable=True)
        self.b = self.add_weight(shape=(input_shape[-1],),
                                 initializer='zeros',
                                 trainable=True)
        self.u = self.add_weight(shape=(input_shape[-1],),
                                 initializer='glorot_uniform',
                                 trainable=True)
        super(AttentionLayer, self).build(input_shape)

    def call(self, x):
        score = tf.nn.tanh(tf.tensordot(x, self.W, axes=[-1, 0]) + self.b)
        attention_weights = tf.nn.softmax(tf.tensordot(score, self.u, axes=[-1, 0]), axis=1)
        attention_weights = tf.expand_dims(attention_weights, axis=-1)
        weighted_sum = x * attention_weights
        return weighted_sum

# Residual Block
def residual_block(x, filters, kernel_size=3, stride=1):
    shortcut = x
    x = Conv2D(filters, kernel_size, strides=stride, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = Conv2D(filters, kernel_size, strides=1, padding='same')(x)
    x = BatchNormalization()(x)

    if stride != 1 or shortcut.shape[-1] != filters:
        shortcut = Conv2D(filters, kernel_size=1, strides=stride, padding='same')(shortcut)
        shortcut = BatchNormalization()(shortcut)

    x = Add()([x, shortcut])
    x = ReLU()(x)
    return x

# Custom CNN Model with EfficientNetB0 as base
def build_custom_cnn(input_shape=(224, 224, 3), num_classes=2):
    base_model = EfficientNetB0(include_top=False, input_shape=input_shape, weights='imagenet')
    base_model.trainable = False

    inputs = Input(shape=input_shape)
    x = base_model(inputs, training=False)

    # Make sure the residual block matches the base model output shape
    x = residual_block(x, x.shape[-1])
    x = residual_block(x, 256)
    x = residual_block(x, 512)

    x = AttentionLayer()(x)  # Apply attention mechanism here

    x = GlobalAveragePooling2D()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

# Build and compile the model
custom_cnn_model = build_custom_cnn()
custom_cnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
custom_cnn_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  efficientnetb0 (Functional)    (None, 7, 7, 1280)   4049571     ['input_2[0][0]']
#
#  conv2d (Conv2D)                (None, 7, 7, 1280)   14746880    ['efficientnetb0[0][0]']
#
#  batch_normalization (BatchNorm  (None, 7, 7, 1280)  5120        ['conv2d[0][0]']
#  alization)
#
#  re_lu (ReLU)                   (None, 7, 7, 1280)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 7, 7, 1280)   14746880    ['re_lu[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 7, 7, 1280)  5120        ['conv2d_1[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 7, 7, 1280)   0           ['batch_normalization_1[0][0]',
#                                                                   'efficientnetb0[0][0]']
#
#  re_lu_1 (ReLU)                 (None, 7, 7, 1280)   0           ['add[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 7, 7, 256)    2949376     ['re_lu_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 7, 7, 256)   1024        ['conv2d_2[0][0]']
#  rmalization)
#
#  re_lu_2 (ReLU)                 (None, 7, 7, 256)    0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 7, 7, 256)    590080      ['re_lu_2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 7, 7, 256)    327936      ['re_lu_1[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 7, 7, 256)   1024        ['conv2d_3[0][0]']
#  rmalization)
#
#  batch_normalization_4 (BatchNo  (None, 7, 7, 256)   1024        ['conv2d_4[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 7, 7, 256)    0           ['batch_normalization_3[0][0]',
#                                                                   'batch_normalization_4[0][0]']
#
#  re_lu_3 (ReLU)                 (None, 7, 7, 256)    0           ['add_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 7, 7, 512)    1180160     ['re_lu_3[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 7, 7, 512)   2048        ['conv2d_5[0][0]']
#  rmalization)
#
#  re_lu_4 (ReLU)                 (None, 7, 7, 512)    0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 7, 7, 512)    2359808     ['re_lu_4[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 7, 7, 512)    131584      ['re_lu_3[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 7, 7, 512)   2048        ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 7, 7, 512)   2048        ['conv2d_7[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 7, 7, 512)    0           ['batch_normalization_6[0][0]',
#                                                                   'batch_normalization_7[0][0]']
#
#  re_lu_5 (ReLU)                 (None, 7, 7, 512)    0           ['add_2[0][0]']
#
#  attention_layer (AttentionLaye  (None, 7, 7, 512)   263168      ['re_lu_5[0][0]']
#  r)
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['attention_layer[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 512)          262656      ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dropout (Dropout)              (None, 512)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 2)            1026        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 41,628,581
# Trainable params: 37,569,282
# Non-trainable params: 4,059,299
# __________________________________________________________________________________________________

# %%
# Data Augmentation and Generators
data_aug_train = ImageDataGenerator(
    height_shift_range=0.15,
    width_shift_range=0.15,
    rotation_range=10,
    shear_range=0.1,
    fill_mode='nearest',
    zoom_range=0.2,
    horizontal_flip=True
)

train_generator = data_aug_train.flow_from_directory(
    r'D:\New folder\140k Real and Fake Faces\real_vs_fake\real-vs-fake\train',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    color_mode='rgb',
    classes=['fake', 'real'],
    seed=2,
    shuffle=True,
    interpolation='lanczos'
)

data_aug_val = ImageDataGenerator()

val_generator = data_aug_val.flow_from_directory(
    r'D:\New folder\140k Real and Fake Faces\real_vs_fake\real-vs-fake\valid',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    color_mode='rgb',
    classes=['fake', 'real'],
    seed=2,
    shuffle=True,
    interpolation='lanczos'
)

data_aug_test = ImageDataGenerator()

test_generator = data_aug_test.flow_from_directory(
    r'D:\New folder\140k Real and Fake Faces\real_vs_fake\real-vs-fake\test',
    target_size=(224, 224),
    batch_size=205,
    class_mode='categorical',
    color_mode='rgb',
    classes=['fake', 'real'],
    shuffle=False,
    interpolation='lanczos'
)

# Callbacks
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.00001)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
# Out:
# Found 100000 images belonging to 2 classes.
# Found 20000 images belonging to 2 classes.
# Found 20000 images belonging to 2 classes.

# %%
import IPython
from IPython.display import display, Javascript
import threading
import time

def keep_alive_javascript():
    display(Javascript('''
        function KeepAlive() {
            console.log("Keeping alive");
            setInterval(function() {
                console.log("Sending keep-alive request");
                fetch("/", {method: "GET", keepalive: true});
            }, 60000);
        }
        KeepAlive();
    '''))

def background_keep_alive():
    while True:
        time.sleep(60)
        print("Background task running to keep the notebook alive...")

# Run the JavaScript keep-alive function
keep_alive_javascript()

# Start the background keep-alive thread
thread = threading.Thread(target=background_keep_alive)
thread.start()
# Out:
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# ...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...
# Background task running to keep the notebook alive...

# %%
# !pip install Pillow
# !pip install h5py
# !pip install scikit-plot
# Out:
# Requirement already satisfied: Pillow in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (10.3.0)
# Requirement already satisfied: h5py in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (3.11.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from h5py) (1.26.4)
# Requirement already satisfied: scikit-plot in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (0.3.7)
# Requirement already satisfied: matplotlib>=1.4.0 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from scikit-plot) (3.9.0)
# Requirement already satisfied: scikit-learn>=0.18 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from scikit-plot) (1.5.0)
# Requirement already satisfied: scipy>=0.9 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from scikit-plot) (1.13.1)
# Requirement already satisfied: joblib>=0.10 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from scikit-plot) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (6.4.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from scikit-learn>=0.18->scikit-plot) (3.5.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=1.4.0->scikit-plot) (3.19.2)
# Requirement already satisfied: six>=1.5 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->scikit-plot) (1.16.0)

# %%
pip install Pillow
# Out:
# Requirement already satisfied: Pillow in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (10.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import PIL

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, roc_auc_score
from tensorflow.keras.models import load_model

# Ensure Pillow is installed
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (10.3.0)

# %%
# Train the model
history = custom_cnn_model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    validation_data=val_generator,
    validation_steps=val_generator.samples // val_generator.batch_size,
    epochs=20,
    callbacks=[reduce_lr, early_stopping]
)

# Fine-tune the base model by unfreezing some layers
base_model = custom_cnn_model.layers[1]  # Accessing the base model from the custom model
base_model.trainable = True

# Recompile the model with a lower learning rate for fine-tuning
custom_cnn_model.compile(optimizer=tf.keras.optimizers.Adam(1e-5), loss='categorical_crossentropy', metrics=['accuracy'])

# Continue training the model
history_fine = custom_cnn_model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    validation_data=val_generator,
    validation_steps=val_generator.samples // val_generator.batch_size,
    epochs=20,
    callbacks=[reduce_lr, early_stopping]
)

# Save the best model
custom_cnn_model.save('best_model.h5')
# Out:
# Epoch 1/20
# 3125/3125 [==============================] - 881s 279ms/step - loss: 0.3833 - accuracy: 0.8285 - val_loss: 0.2771 - val_accuracy: 0.8816 - lr: 0.0010
# Epoch 2/20
# 3125/3125 [==============================] - 615s 197ms/step - loss: 0.2789 - accuracy: 0.8848 - val_loss: 0.2108 - val_accuracy: 0.9182 - lr: 0.0010
# Epoch 3/20
# 3125/3125 [==============================] - 623s 199ms/step - loss: 0.2316 - accuracy: 0.9062 - val_loss: 0.1977 - val_accuracy: 0.9193 - lr: 0.0010
# Epoch 4/20
# 3125/3125 [==============================] - 628s 201ms/step - loss: 0.2016 - accuracy: 0.9193 - val_loss: 0.1681 - val_accuracy: 0.9329 - lr: 0.0010
# Epoch 5/20
# 3125/3125 [==============================] - 613s 196ms/step - loss: 0.1780 - accuracy: 0.9295 - val_loss: 0.1561 - val_accuracy: 0.9395 - lr: 0.0010
# Epoch 6/20
# 3125/3125 [==============================] - 625s 200ms/step - loss: 0.1572 - accuracy: 0.9380 - val_loss: 0.1490 - val_accuracy: 0.9413 - lr: 0.0010
# Epoch 7/20
# 3125/3125 [==============================] - 631s 202ms/step - loss: 0.1438 - accuracy: 0.9433 - val_loss: 0.1662 - val_accuracy: 0.9330 - lr: 0.0010
# Epoch 8/20
# 3125/3125 [==============================] - 610s 195ms/step - loss: 0.1308 - accuracy: 0.9496 - val_loss: 0.1258 - val_accuracy: 0.9511 - lr: 0.0010
# Epoch 9/20
# 3125/3125 [==============================] - 593s 190ms/step - loss: 0.1195 - accuracy: 0.9542 - val_loss: 0.1456 - val_accuracy: 0.9444 - lr: 0.0010
# Epoch 10/20
# 3125/3125 [==============================] - 588s 188ms/step - loss: 0.1095 - accuracy: 0.9585 - val_loss: 0.1188 - val_accuracy: 0.9553 - lr: 0.0010
# Epoch 11/20
# 3125/3125 [==============================] - 595s 190ms/step - loss: 0.1036 - accuracy: 0.9602 - val_loss: 0.1254 - val_accuracy: 0.9506 - lr: 0.0010
# Epoch 12/20
# 3125/3125 [==============================] - 597s 191ms/step - loss: 0.0944 - accuracy: 0.9642 - val_loss: 0.0968 - val_accuracy: 0.9635 - lr: 0.0010
# Epoch 13/20
# 3125/3125 [==============================] - 590s 189ms/step - loss: 0.0893 - accuracy: 0.9654 - val_loss: 0.1765 - val_accuracy: 0.9332 - lr: 0.0010
# Epoch 14/20
# 3125/3125 [==============================] - 598s 191ms/step - loss: 0.0845 - accuracy: 0.9683 - val_loss: 0.0950 - val_accuracy: 0.9660 - lr: 0.0010
# Epoch 15/20
# 3125/3125 [==============================] - 590s 189ms/step - loss: 0.0797 - accuracy: 0.9702 - val_loss: 0.1055 - val_accuracy: 0.9602 - lr: 0.0010
# Epoch 16/20
# 3125/3125 [==============================] - 597s 191ms/step - loss: 0.0757 - accuracy: 0.9713 - val_loss: 0.1370 - val_accuracy: 0.9534 - lr: 0.0010
# Epoch 17/20
# 3125/3125 [==============================] - 599s 192ms/step - loss: 0.0725 - accuracy: 0.9729 - val_loss: 0.0983 - val_accuracy: 0.9661 - lr: 0.0010
# Epoch 18/20
# 3125/3125 [==============================] - 636s 204ms/step - loss: 0.0695 - accuracy: 0.9743 - val_loss: 0.0999 - val_accuracy: 0.9621 - lr: 0.0010
# Epoch 19/20
# 3125/3125 [==============================] - 603s 193ms/step - loss: 0.0648 - accuracy: 0.9756 - val_loss: 0.0887 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 20/20
# 3125/3125 [==============================] - 590s 189ms/step - loss: 0.0630 - accuracy: 0.9769 - val_loss: 0.0846 - val_accuracy: 0.9701 - lr: 0.0010
# Epoch 1/10
# 3125/3125 [==============================] - 704s 224ms/step - loss: 0.0361 - accuracy: 0.9872 - val_loss: 0.1018 - val_accuracy: 0.9681 - lr: 1.0000e-05
# Epoch 2/10
# 3125/3125 [==============================] - 697s 223ms/step - loss: 0.0242 - accuracy: 0.9911 - val_loss: 0.1554 - val_accuracy: 0.9524 - lr: 1.0000e-05
# Epoch 3/10
# 3125/3125 [==============================] - 705s 225ms/step - loss: 0.0191 - accuracy: 0.9932 - val_loss: 0.0860 - val_accuracy: 0.9729 - lr: 1.0000e-05
# Epoch 4/10
# 3125/3125 [==============================] - 804s 257ms/step - loss: 0.0158 - accuracy: 0.9947 - val_loss: 0.0586 - val_accuracy: 0.9825 - lr: 1.0000e-05
# Epoch 5/10
# 3125/3125 [==============================] - 713s 228ms/step - loss: 0.0139 - accuracy: 0.9950 - val_loss: 0.0594 - val_accuracy: 0.9823 - lr: 1.0000e-05
# Epoch 6/10
# 3125/3125 [==============================] - 709s 227ms/step - loss: 0.0113 - accuracy: 0.9960 - val_loss: 0.0485 - val_accuracy: 0.9849 - lr: 1.0000e-05
# Epoch 7/10
# 3125/3125 [==============================] - 707s 226ms/step - loss: 0.0102 - accuracy: 0.9964 - val_loss: 0.0734 - val_accuracy: 0.9776 - lr: 1.0000e-05
# Epoch 8/10
# 3125/3125 [==============================] - 702s 225ms/step - loss: 0.0088 - accuracy: 0.9971 - val_loss: 0.0261 - val_accuracy: 0.9908 - lr: 1.0000e-05
# Epoch 9/10
# 3125/3125 [==============================] - 702s 225ms/step - loss: 0.0087 - accuracy: 0.9970 - val_loss: 0.0302 - val_accuracy: 0.9888 - lr: 1.0000e-05
# Epoch 10/10
# 3125/3125 [==============================] - 704s 225ms/step - loss: 0.0075 - accuracy: 0.9972 - val_loss: 0.0466 - val_accuracy: 0.9852 - lr: 1.0000e-05
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 29
#      19 history_fine = custom_cnn_model.fit(
#      20     train_generator,
#      21     steps_per_epoch=train_generator.samples // train_generator.batch_size,
#    (...)
#      25     callbacks=[reduce_lr, early_stopping]
#      26 )
#      28 # Save the best model
# ---> 29 custom_cnn_model.save('best_model.h5')
#
# File ~\anaconda3\envs\my_env\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\envs\my_env\lib\json\__init__.py:234, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     232 if cls is None:
#     233     cls = JSONEncoder
# --> 234 return cls(
#     235     skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236     check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237     separators=separators, default=default, sort_keys=sort_keys,
#     238     **kw).encode(obj)
#
# File ~\anaconda3\envs\my_env\lib\json\encoder.py:199, in JSONEncoder.encode(self, o)
#     195         return encode_basestring(o)
#     196 # This doesn't pass the iterator directly to ''.join() because the
#     197 # exceptions aren't as detailed.  The list call should be roughly
#     198 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199 chunks = self.iterencode(o, _one_shot=True)
#     200 if not isinstance(chunks, (list, tuple)):
#     201     chunks = list(chunks)
#
# File ~\anaconda3\envs\my_env\lib\json\encoder.py:257, in JSONEncoder.iterencode(self, o, _one_shot)
#     252 else:
#     253     _iterencode = _make_iterencode(
#     254         markers, self.default, _encoder, self.indent, floatstr,
#     255         self.key_separator, self.item_separator, self.sort_keys,
#     256         self.skipkeys, _one_shot)
# --> 257 return _iterencode(o, 0)
#
# TypeError: Unable to serialize [2.0896919 2.1128857 2.1081853] to JSON. Unrecognized type <class 'tensorflow.python.framework.ops.EagerTensor'>.

# %%
# Train accuracy, test accuracy, test loss
train_accuracy = history.history['accuracy'][-1]
test_loss, test_accuracy = custom_cnn_model.evaluate(test_generator)

print(f'Training Accuracy: {train_accuracy:.4f}')
print(f'Test Accuracy: {test_accuracy:.4f}')
print(f'Test Loss: {test_loss:.4f}')
# Out:
# 98/98 [==============================] - 76s 772ms/step - loss: 0.0505 - accuracy: 0.9851
# Training Accuracy: 0.9769
# Test Accuracy: 0.9851
# Test Loss: 0.0505

# %%
# Train vs test accuracy plot
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'] + history_fine.history['accuracy'])
plt.plot(history.history['val_accuracy'] + history_fine.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# %%
# Assuming you have y_true and y_pred obtained from your model predictions
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Compute ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_true, y_pred)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'] + history_fine.history['accuracy'])
plt.plot(history.history['val_accuracy'] + history_fine.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'] + history_fine.history['loss'])
plt.plot(history.history['val_loss'] + history_fine.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# Evaluate the model
test_loss, test_acc = custom_cnn_model.evaluate(test_generator)
print('Test accuracy:', test_acc)

# Predict the test set
predictions = custom_cnn_model.predict(test_generator)
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes
# Out:
# 98/98 [==============================] - 36s 358ms/step - loss: 0.0505 - accuracy: 0.9851
# Test accuracy: 0.9851499795913696
# 98/98 [==============================] - 36s 356ms/step

# %%
# Print classification report
print(classification_report(y_true, y_pred, target_names=test_generator.class_indices.keys()))
# Out:
#               precision    recall  f1-score   support
#
#         fake       1.00      0.97      0.98     10000
#         real       0.97      1.00      0.99     10000
#
#     accuracy                           0.99     20000
#    macro avg       0.99      0.99      0.99     20000
# weighted avg       0.99      0.99      0.99     20000

# %%
# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %% [markdown]
# LIME

# %%
# Install necessary libraries
# !pip install lime
# !pip install scikit-image
# Out:
# Collecting lime
#   Using cached lime-0.2.0.1-py3-none-any.whl
# Requirement already satisfied: matplotlib in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from lime) (3.9.0)
# Requirement already satisfied: numpy in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from lime) (1.26.4)
# Requirement already satisfied: scipy in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from lime) (1.13.1)
# Collecting tqdm (from lime)
#   Using cached tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: scikit-learn>=0.18 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from lime) (1.5.0)
# Collecting scikit-image>=0.12 (from lime)
#   Using cached scikit_image-0.22.0-cp39-cp39-win_amd64.whl.metadata (13 kB)
# Collecting networkx>=2.8 (from scikit-image>=0.12->lime)
#   Using cached networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: pillow>=9.0.1 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from scikit-image>=0.12->lime) (10.3.0)
# Collecting imageio>=2.27 (from scikit-image>=0.12->lime)
#   Using cached imageio-2.34.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image>=0.12->lime)
#   Using cached tifffile-2024.5.22-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: packaging>=21 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from scikit-image>=0.12->lime) (24.1)
# Collecting lazy_loader>=0.3 (from scikit-image>=0.12->lime)
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from scikit-learn>=0.18->lime) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from scikit-learn>=0.18->lime) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib->lime) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib->lime) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib->lime) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib->lime) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib->lime) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib->lime) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from matplotlib->lime) (6.4.0)
# Requirement already satisfied: colorama in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from tqdm->lime) (0.4.6)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->lime) (3.19.2)
# Requirement already satisfied: six>=1.5 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from python-dateutil>=2.7->matplotlib->lime) (1.16.0)
# Using cached scikit_image-0.22.0-cp39-cp39-win_amd64.whl (24.5 MB)
# Using cached tqdm-4.66.4-py3-none-any.whl (78 kB)
# Using cached imageio-2.34.1-py3-none-any.whl (313 kB)
# Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Using cached networkx-3.2.1-py3-none-any.whl (1.6 MB)
# Using cached tifffile-2024.5.22-py3-none-any.whl (225 kB)
# Installing collected packages: tqdm, tifffile, networkx, lazy_loader, imageio, scikit-image, lime
# Successfully installed imageio-2.34.1 lazy_loader-0.4 lime-0.2.0.1 networkx-3.2.1 scikit-image-0.22.0 tifffile-2024.5.22 tqdm-4.66.4
# Requirement already satisfied: scikit-image in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (0.22.0)
# Requirement already satisfied: numpy>=1.22 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from scikit-image) (1.26.4)
# Requirement already satisfied: scipy>=1.8 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from scikit-image) (1.13.1)
# Requirement already satisfied: networkx>=2.8 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from scikit-image) (3.2.1)
# Requirement already satisfied: pillow>=9.0.1 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from scikit-image) (10.3.0)
# Requirement already satisfied: imageio>=2.27 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from scikit-image) (2.34.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from scikit-image) (2024.5.22)
# Requirement already satisfied: packaging>=21 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from scikit-image) (24.1)
# Requirement already satisfied: lazy_loader>=0.3 in c:\users\dial\anaconda3\envs\my_env\lib\site-packages (from scikit-image) (0.4)

# %%
import lime
from lime import lime_image
from lime.wrappers.scikit_image import SegmentationAlgorithm
from skimage.segmentation import mark_boundaries
from sklearn.metrics.pairwise import cosine_similarity
